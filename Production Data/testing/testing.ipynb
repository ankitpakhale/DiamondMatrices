# %%
import cv2
import numpy as np
from PIL import Image
from skimage.feature import corner_harris, corner_subpix, corner_peaks

# %%
img = cv2.imread("147.jpg")

# %%
print(img.shape)
# The image with shape (1280, 1024, 3) has a resolution of 1280 pixels by 1024 pixels and has 3 color channels, which means it is a color image.
# Out:
# (1280, 1024, 3)

# %%
print(img.size)
# Out:
# 3932160

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
blur_img = cv2.GaussianBlur(gray_img, (5, 5), 0)

# %%
# Compute Harris corners
corners = corner_harris(blur_img, k=0.04)
corners
# Out:
# array([[ 5.25046409e-07,  6.37126749e-07,  1.87674659e-07, ...,
#          8.41628209e-06,  6.84258877e-05,  6.68851401e-05],
#        [ 4.60584155e-07,  5.49769319e-07,  1.71791356e-07, ...,
#          1.60742806e-05,  7.40552337e-05,  7.29489797e-05],
#        [ 6.05980174e-08,  2.16746674e-08, -3.72703946e-08, ...,
#          5.59365150e-06,  1.93729362e-05,  1.44620127e-05],
#        ...,
#        [ 3.86350126e-06,  5.77160266e-06,  2.20002774e-06, ...,
#          9.40897948e-05,  2.86784645e-04,  1.33325008e-04],
#        [ 2.29084823e-05,  2.75182483e-05,  9.74893105e-06, ...,
#          1.89039629e-04,  7.85309431e-04,  6.54708938e-04],
#        [ 2.13651664e-05,  2.52299363e-05,  7.65693018e-06, ...,
#          7.07204792e-05,  6.11960224e-04,  5.41022314e-04]])

# %%
# Subpixel corner refinement
corners = corner_subpix(blur_img, corners, window_size=13)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\_shared\utils.py in safe_as_int(val, atol)
#     557     try:
# --> 558         np.testing.assert_allclose(mod, 0, atol=atol)
#     559     except AssertionError:
#
#     [... skipping hidden 1 frame]
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     843                                 names=('x', 'y'), precision=precision)
# --> 844             raise AssertionError(msg)
#     845     except ValueError:
#
# AssertionError:
# Not equal to tolerance rtol=1e-07, atol=0.001
#
# Mismatched elements: 10826 / 1310720 (0.826%)
# Max absolute difference: 0.02054958
# Max relative difference: inf
#  x: array([[5.250464e-07, 6.371267e-07, 1.876747e-07, ..., 8.416282e-06,
#         6.842589e-05, 6.688514e-05],
#        [4.605842e-07, 5.497693e-07, 1.717914e-07, ..., 1.607428e-05,...
#  y: array(0)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7692\2510235229.py in <module>
#       1 # Subpixel corner refinement
# ----> 2 corners = corner_subpix(blur_img, corners, window_size=13)
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\feature\corner.py in corner_subpix(image, corners, window_size, alpha)
#     908
#     909     # add pad width, make sure to not modify the input values in-place
# --> 910     corners = safe_as_int(corners + wext)
#     911
#     912     # normal equation arrays
#
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\_shared\utils.py in safe_as_int(val, atol)
#     558         np.testing.assert_allclose(mod, 0, atol=atol)
#     559     except AssertionError:
# --> 560         raise ValueError(f'Integer argument required but received '
#     561                          f'{val}, check inputs.')
#     562
#
# ValueError: Integer argument required but received [[6.00000053 6.00000064 6.00000019 ... 6.00000842 6.00006843 6.00006689]
#  [6.00000046 6.00000055 6.00000017 ... 6.00001607 6.00007406 6.00007295]
#  [6.00000006 6.00000002 5.99999996 ... 6.00000559 6.00001937 6.00001446]
#  ...
#  [6.00000386 6.00000577 6.0000022  ... 6.00009409 6.00028678 6.00013333]
#  [6.00002291 6.00002752 6.00000975 ... 6.00018904 6.00078531 6.00065471]
#  [6.00002137 6.00002523 6.00000766 ... 6.00007072 6.00061196 6.00054102]], check inputs.

# %%
# Find the peaks of the corners
coords = corner_peaks(corners, min_distance=5)
coords
# Out:
# array([[379, 361],
#        [730, 668],
#        [725, 643],
#        ...,
#        [108,  22],
#        [  5,  50],
#        [ 53,  43]], dtype=int64)

# %%
# Find contours
contours, hierarchy = cv2.findContours(blur_img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print(contours, hierarchy)
# Out:
# (array([[[   0,    0]],
#
#        [[   0, 1279]],
#
#        [[1023, 1279]],
#
#        [[1023,    0]],
#
#        [[ 547,    0]],
#
#        [[ 546,    1]],
#
#        [[ 545,    1]],
#
#        [[ 544,    0]],
#
#        [[ 523,    0]],
#
#        [[ 523,    5]],
#
#        [[ 521,    7]],
#
#        [[ 520,    6]],
#
#        [[ 520,    0]],
#
#        [[   9,    0]],
#
#        [[   9,    7]],
#
#        [[   8,    8]],
#
#        [[   3,    8]],
#
#        [[   2,    7]],
#
#        [[   2,    0]]], dtype=int32), array([[[ 134, 1169]],
#
#        [[ 135, 1168]],
#
#        [[ 136, 1169]],
#
#        [[ 135, 1170]]], dtype=int32), array([[[  5, 275]],
#
#        [[  6, 274]],
#
#        [[  7, 274]],
#
#        [[  8, 275]],
#
#        [[  8, 276]],
#
#        [[  7, 277]]], dtype=int32), array([[[ 29, 253]],
#
#        [[ 30, 252]],
#
#        [[ 31, 252]],
#
#        [[ 32, 253]],
#
#        [[ 32, 254]],
#
#        [[ 30, 256]],
#
#        [[ 29, 255]]], dtype=int32), array([[[ 25, 248]],
#
#        [[ 26, 247]],
#
#        [[ 28, 249]],
#
#        [[ 28, 250]],
#
#        [[ 27, 251]],
#
#        [[ 26, 251]],
#
#        [[ 25, 250]]], dtype=int32), array([[[  4, 225]],
#
#        [[  5, 224]],
#
#        [[  6, 225]],
#
#        [[  5, 226]]], dtype=int32), array([[[ 19, 224]],
#
#        [[ 20, 223]],
#
#        [[ 23, 223]],
#
#        [[ 25, 225]],
#
#        [[ 25, 226]],
#
#        [[ 24, 227]],
#
#        [[ 21, 227]],
#
#        [[ 19, 225]]], dtype=int32), array([[[  8, 217]],
#
#        [[  9, 216]],
#
#        [[ 10, 216]],
#
#        [[ 11, 217]],
#
#        [[ 11, 221]],
#
#        [[ 10, 222]],
#
#        [[  9, 222]],
#
#        [[  8, 221]]], dtype=int32), array([[[ 11, 193]],
#
#        [[ 12, 192]],
#
#        [[ 13, 193]],
#
#        [[ 12, 194]]], dtype=int32), array([[[  6, 187]],
#
#        [[  7, 186]],
#
#        [[  8, 186]],
#
#        [[ 10, 188]],
#
#        [[  9, 189]],
#
#        [[  7, 189]],
#
#        [[  6, 188]]], dtype=int32), array([[[ 19, 177]],
#
#        [[ 20, 176]],
#
#        [[ 21, 177]],
#
#        [[ 20, 178]]], dtype=int32), array([[[  7, 149]],
#
#        [[  8, 148]],
#
#        [[ 10, 148]],
#
#        [[ 12, 150]],
#
#        [[ 11, 151]],
#
#        [[  9, 151]]], dtype=int32), array([[[ 26, 144]],
#
#        [[ 27, 143]],
#
#        [[ 30, 143]],
#
#        [[ 31, 144]],
#
#        [[ 31, 146]],
#
#        [[ 29, 148]],
#
#        [[ 28, 148]],
#
#        [[ 26, 146]]], dtype=int32), array([[[ 15, 143]],
#
#        [[ 16, 142]],
#
#        [[ 18, 144]],
#
#        [[ 18, 146]],
#
#        [[ 19, 147]],
#
#        [[ 19, 148]],
#
#        [[ 18, 149]],
#
#        [[ 17, 149]],
#
#        [[ 16, 148]],
#
#        [[ 16, 147]],
#
#        [[ 14, 147]],
#
#        [[ 13, 146]],
#
#        [[ 13, 144]],
#
#        [[ 14, 143]]], dtype=int32), array([[[  8, 137]],
#
#        [[  9, 136]],
#
#        [[ 10, 136]],
#
#        [[ 11, 137]],
#
#        [[ 11, 141]],
#
#        [[  9, 143]],
#
#        [[  8, 142]]], dtype=int32), array([[[ 32, 123]],
#
#        [[ 33, 122]],
#
#        [[ 38, 122]],
#
#        [[ 39, 123]],
#
#        [[ 39, 124]],
#
#        [[ 38, 125]],
#
#        [[ 33, 125]],
#
#        [[ 32, 124]]], dtype=int32), array([[[ 22, 120]],
#
#        [[ 23, 119]],
#
#        [[ 24, 119]],
#
#        [[ 25, 120]],
#
#        [[ 25, 121]],
#
#        [[ 24, 122]],
#
#        [[ 23, 122]],
#
#        [[ 22, 121]]], dtype=int32), array([[[ 18, 119]],
#
#        [[ 19, 120]],
#
#        [[ 19, 121]],
#
#        [[ 18, 122]],
#
#        [[ 17, 122]],
#
#        [[ 16, 121]]], dtype=int32), array([[[ 53, 115]],
#
#        [[ 54, 114]],
#
#        [[ 55, 114]],
#
#        [[ 56, 115]],
#
#        [[ 56, 116]],
#
#        [[ 55, 117]],
#
#        [[ 54, 117]],
#
#        [[ 53, 116]]], dtype=int32), array([[[ 39, 111]],
#
#        [[ 41, 113]],
#
#        [[ 41, 118]],
#
#        [[ 40, 119]],
#
#        [[ 38, 119]],
#
#        [[ 37, 118]],
#
#        [[ 37, 113]]], dtype=int32), array([[[  7,  99]],
#
#        [[  8,  98]],
#
#        [[  9,  99]],
#
#        [[  9, 100]],
#
#        [[  8, 101]],
#
#        [[  7, 100]]], dtype=int32), array([[[ 40,  96]],
#
#        [[ 41,  95]],
#
#        [[ 42,  95]],
#
#        [[ 44,  97]],
#
#        [[ 44, 102]],
#
#        [[ 42, 104]],
#
#        [[ 40, 102]]], dtype=int32), array([[[50, 89]],
#
#        [[51, 88]],
#
#        [[53, 88]],
#
#        [[54, 89]],
#
#        [[54, 94]],
#
#        [[52, 96]],
#
#        [[50, 94]]], dtype=int32), array([[[34, 87]],
#
#        [[39, 87]],
#
#        [[41, 89]],
#
#        [[41, 95]],
#
#        [[40, 96]],
#
#        [[34, 96]],
#
#        [[32, 94]],
#
#        [[32, 89]]], dtype=int32), array([[[18, 87]],
#
#        [[23, 87]],
#
#        [[25, 89]],
#
#        [[25, 94]],
#
#        [[23, 96]],
#
#        [[18, 96]],
#
#        [[16, 94]],
#
#        [[16, 89]]], dtype=int32), array([[[13, 78]],
#
#        [[14, 77]],
#
#        [[16, 77]],
#
#        [[17, 78]],
#
#        [[15, 80]],
#
#        [[14, 80]],
#
#        [[13, 79]]], dtype=int32), array([[[ 3, 70]],
#
#        [[ 4, 69]],
#
#        [[ 5, 69]],
#
#        [[ 6, 70]],
#
#        [[ 5, 71]],
#
#        [[ 4, 71]]], dtype=int32), array([[[ 9, 63]],
#
#        [[16, 63]],
#
#        [[17, 64]],
#
#        [[17, 70]],
#
#        [[16, 71]],
#
#        [[13, 71]],
#
#        [[12, 72]],
#
#        [[12, 73]],
#
#        [[10, 75]],
#
#        [[ 8, 73]],
#
#        [[ 9, 72]],
#
#        [[ 9, 68]],
#
#        [[ 8, 67]],
#
#        [[ 8, 66]],
#
#        [[ 7, 65]]], dtype=int32), array([[[485,  55]],
#
#        [[486,  56]],
#
#        [[486,  62]],
#
#        [[485,  63]],
#
#        [[483,  61]],
#
#        [[483,  57]]], dtype=int32), array([[[26, 52]],
#
#        [[28, 54]],
#
#        [[28, 62]],
#
#        [[26, 64]],
#
#        [[17, 64]],
#
#        [[16, 63]],
#
#        [[16, 57]],
#
#        [[18, 55]],
#
#        [[23, 55]]], dtype=int32), array([[[499,  48]],
#
#        [[500,  47]],
#
#        [[501,  47]],
#
#        [[502,  48]],
#
#        [[502,  54]],
#
#        [[500,  56]],
#
#        [[498,  56]],
#
#        [[496,  54]],
#
#        [[496,  49]],
#
#        [[497,  48]]], dtype=int32), array([[[29, 48]],
#
#        [[30, 47]],
#
#        [[31, 47]],
#
#        [[33, 49]],
#
#        [[32, 50]],
#
#        [[30, 50]],
#
#        [[29, 49]]], dtype=int32), array([[[523,  41]],
#
#        [[524,  40]],
#
#        [[525,  40]],
#
#        [[526,  41]],
#
#        [[526,  46]],
#
#        [[525,  47]],
#
#        [[524,  47]],
#
#        [[523,  46]]], dtype=int32), array([[[501,  41]],
#
#        [[502,  40]],
#
#        [[503,  40]],
#
#        [[504,  41]],
#
#        [[504,  46]],
#
#        [[503,  47]],
#
#        [[502,  47]],
#
#        [[501,  46]]], dtype=int32), array([[[24, 32]],
#
#        [[25, 31]],
#
#        [[32, 31]],
#
#        [[33, 32]],
#
#        [[33, 38]],
#
#        [[31, 40]],
#
#        [[26, 40]],
#
#        [[24, 38]]], dtype=int32), array([[[32, 25]],
#
#        [[33, 24]],
#
#        [[34, 24]],
#
#        [[35, 25]],
#
#        [[35, 30]],
#
#        [[33, 32]],
#
#        [[32, 31]]], dtype=int32), array([[[501,  23]],
#
#        [[502,  23]],
#
#        [[504,  25]],
#
#        [[504,  30]],
#
#        [[503,  31]],
#
#        [[500,  31]],
#
#        [[499,  30]],
#
#        [[499,  25]]], dtype=int32), array([[[10, 23]],
#
#        [[16, 23]],
#
#        [[18, 25]],
#
#        [[18, 31]],
#
#        [[17, 32]],
#
#        [[17, 38]],
#
#        [[15, 40]],
#
#        [[10, 40]],
#
#        [[ 9, 41]],
#
#        [[ 9, 46]],
#
#        [[ 7, 48]],
#
#        [[ 4, 48]],
#
#        [[ 3, 49]],
#
#        [[ 2, 48]],
#
#        [[ 2, 33]],
#
#        [[ 3, 32]],
#
#        [[ 4, 32]],
#
#        [[ 5, 31]],
#
#        [[ 7, 31]],
#
#        [[ 8, 30]],
#
#        [[ 8, 25]]], dtype=int32), array([[[525,  23]],
#
#        [[526,  22]],
#
#        [[527,  23]],
#
#        [[526,  24]]], dtype=int32), array([[[528,  22]],
#
#        [[529,  21]],
#
#        [[530,  22]],
#
#        [[529,  23]]], dtype=int32), array([[[50, 15]],
#
#        [[52, 17]],
#
#        [[52, 22]],
#
#        [[50, 24]],
#
#        [[48, 22]],
#
#        [[48, 17]]], dtype=int32), array([[[521,  13]],
#
#        [[522,  12]],
#
#        [[527,  12]],
#
#        [[529,  14]],
#
#        [[529,  15]],
#
#        [[530,  16]],
#
#        [[530,  17]],
#
#        [[529,  18]],
#
#        [[528,  18]],
#
#        [[527,  17]],
#
#        [[523,  17]],
#
#        [[521,  15]]], dtype=int32), array([[[515,   9]],
#
#        [[516,   8]],
#
#        [[517,   8]],
#
#        [[518,   9]],
#
#        [[518,  14]],
#
#        [[517,  15]],
#
#        [[516,  15]],
#
#        [[515,  14]]], dtype=int32), array([[[507,   9]],
#
#        [[508,   8]],
#
#        [[509,   8]],
#
#        [[510,   9]],
#
#        [[510,  14]],
#
#        [[509,  15]],
#
#        [[508,  15]],
#
#        [[507,  14]]], dtype=int32), array([[[25,  7]],
#
#        [[31,  7]],
#
#        [[33,  9]],
#
#        [[33, 14]],
#
#        [[31, 16]],
#
#        [[25, 16]],
#
#        [[23, 14]],
#
#        [[23,  9]]], dtype=int32), array([[[ 8,  8]],
#
#        [[ 9,  7]],
#
#        [[16,  7]],
#
#        [[18,  9]],
#
#        [[18, 14]],
#
#        [[16, 16]],
#
#        [[10, 16]],
#
#        [[ 8, 14]]], dtype=int32), array([[[490,   4]],
#
#        [[496,   4]],
#
#        [[497,   5]],
#
#        [[497,   6]],
#
#        [[496,   7]],
#
#        [[489,   7]],
#
#        [[488,   6]]], dtype=int32)) [[[-1 -1  1 -1]
#   [ 2 -1 -1  0]
#   [ 3  1 -1  0]
#   [ 4  2 -1  0]
#   [ 5  3 -1  0]
#   [ 6  4 -1  0]
#   [ 7  5 -1  0]
#   [ 8  6 -1  0]
#   [ 9  7 -1  0]
#   [10  8 -1  0]
#   [11  9 -1  0]
#   [12 10 -1  0]
#   [13 11 -1  0]
#   [14 12 -1  0]
#   [15 13 -1  0]
#   [16 14 -1  0]
#   [17 15 -1  0]
#   [18 16 -1  0]
#   [19 17 -1  0]
#   [20 18 -1  0]
#   [21 19 -1  0]
#   [22 20 -1  0]
#   [23 21 -1  0]
#   [24 22 -1  0]
#   [25 23 -1  0]
#   [26 24 -1  0]
#   [27 25 -1  0]
#   [28 26 -1  0]
#   [29 27 -1  0]
#   [30 28 -1  0]
#   [31 29 -1  0]
#   [32 30 -1  0]
#   [33 31 -1  0]
#   [34 32 -1  0]
#   [35 33 -1  0]
#   [36 34 -1  0]
#   [37 35 -1  0]
#   [38 36 -1  0]
#   [39 37 -1  0]
#   [40 38 -1  0]
#   [41 39 -1  0]
#   [42 40 -1  0]
#   [43 41 -1  0]
#   [44 42 -1  0]
#   [45 43 -1  0]
#   [46 44 -1  0]
#   [-1 45 -1  0]]]

# %%
# Draw contours
cv2.drawContours(img, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [ 12,  12,  12],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        ...,
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  4,   4,   4],
#         ...,
#         [ 30,  30,  30],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)

# %%
# SIFT Feature Detection
sift = cv2.xfeatures2d.SIFT_create()
kp, des = sift.detectAndCompute(gray_img, None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7692\1164820651.py in <module>
#       1 # SIFT Feature Detection
# ----> 2 sift = cv2.xfeatures2d.SIFT_create()
#       3 kp, des = sift.detectAndCompute(gray_img, None)
#
# AttributeError: module 'cv2' has no attribute 'xfeatures2d'

# %%
# Draw keypoints on the image
img_with_keypoints = cv2.drawKeypoints(img, kp, None)
